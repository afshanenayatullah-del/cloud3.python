# %%
# variables
var = 43

# var1 = input("enter number")

#A-Z,a-z,0-9,_

r2ate3 = 234
user_name = "alex"

print(user_name)
# Out:
# alex

# %%
num = 10 
var = num * 2 

var23 = 324524

var4 = input("Enter something: ")

print(var)
print(var4)

# %%
bas = input("type something: ")
print(bas)
# Out:
# adfa

# %%
def dsfg():
    print("asdfa")
    print("asdf")
    print("afsda")
dsfg()

# %%
import builtins
print(dir(builtins))
dir()
