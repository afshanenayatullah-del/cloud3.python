# %%
# Conditional statements

# if -- ome block one option
# if-else -- two blocks two options
# if-elif-else -- multiple blocks

# %%
# conditional operators

# > greater than
# < less than
# >= greater than or equal to
# <= less than or equal to
# == equal to
# != not equal to

# %%
10 > 100
# Out:
# False

# %%
marks = 65
passing  = 60

marks >= passing
# Out:
# True

# %%
if marks >= passing:
    print("pass")
# Out:
# pass

# %%
marks = 50 
passing = 60

if marks >= passing:
    print("pass")   
else:
    print("fail")
# Out:
# fail

# %%
marks = 65
passing = 60

if marks >= passing:
    print("congragulations you're passed you're obtained", marks)
else:
    print("sorry you're failed. try again")
